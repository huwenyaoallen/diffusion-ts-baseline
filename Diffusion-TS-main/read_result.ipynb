# %%
import numpy as np

pred = np.load('./OUTPUT/etth/ddpm_predict_etth.npy')
real = np.load('./OUTPUT/etth/ddpm_predict_etth_real.npy')

# %%
pred.shape
# Out:
# (2857, 2, 24, 7)

# %%
real.shape
# Out:
# (2857, 24, 7)

# %%
import matplotlib.pyplot as plt

idx = 1670
channel = 3
sample_num = 2
for i in range(sample_num):
    plt.plot(pred[idx, i, :, channel], label='pred', alpha=0.5, color='blue')
plt.plot(real[idx, :, channel], label='real', color='red')
# plt.plot(masks[idx, :, channel], label='mask')
plt.legend()

# %%
real[idx, :, channel]
# Out:
# array([-0.14752331, -0.05512201, -0.05512201, -0.07380992, -0.18438004,
#        -0.07380992, -0.05512201,  0.4427031 ,  0.4427031 ,  0.6456746 ,
#         0.7931014 ,  0.7562447 ,  1.365159  ,  1.2359011 ,  0.68253136,
#         0.6088179 ,  0.4982477 ,  0.6088179 ,  0.7931014 ,  0.18470617,
#         0.3503018 ,  0.40584642, -0.16621123,  0.38715848], dtype=float32)
